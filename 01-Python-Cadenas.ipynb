# %% [markdown]
# ## Indexación
# En esta sección, se realizan ejercicios orientados a comprender cómo acceder a los caracteres individuales de una cadena mediante el uso de índices. A través de diferentes ejemplos, se identifica la posición que ocupa cada carácter dentro de una cadena y se analiza la forma en la que Python numera los elementos almacenados en una variable de tipo texto.

# %%
print("hello!")
# Out:
# hello!

# %%
Name = "Michael Jackson"
Name
# Out:
# 'Michael Jackson'

# %%
# Imprime el primer elemento de la cadena
print(Name[0])
# Out:
# M

# %%
# Imprime el elemento en el índice 6 de la cadena
print(Name[6])
# Out:
# l

# %%
# Imprime el elemento en el treceavo índice de la cadena
print(Name[13])
# Out:
# o

# %% [markdown]
# ## Indexación Negativa
# En esta sección, se explora el uso de índices negativos para acceder a los caracteres de una cadena comenzando desde el final. Mediante distintos ejercicios, se demuestra cómo Python permite recorrer una cadena en sentido inverso, facilitando el acceso a los últimos elementos sin necesidad de conocer su longitud.

# %%
# Imprime el último elemento de la cadena
print(Name[-1])
# Out:
# n

# %%
# Imprime el primer elemento de la cadena
print(Name[-15])
# Out:
# M

# %%
# Encuentra la longitud de la cadena
len("Michael Jackson")
# Out:
# 15

# %% [markdown]
# ## Slicing
# En esta sección, se desarrollan ejercicios relacionados con la extracción de fragmentos específicos de una cadena mediante el uso de la técnica conocida como slicing. A través de diferentes ejemplos, se analiza cómo seleccionar intervalos de caracteres definiendo posiciones iniciales y finales.

# %%
# Asigna una seccion de la cadena dentro de la variable Name usando los indices desde el 0 hasta el 3
Name[0:4]
# Out:
# 'Mich'

# %%
# Asigna una seccion de la cadena dentro de la variable Name usando los indices desde el 8 hasta el 11
Name[8:12]
# Out:
# 'Jack'

# %% [markdown]
# ## Stride
# En esta sección, se implementan ejercicios para comprender el funcionamiento del parámetro stride, el cual permite establecer el intervalo entre los elementos seleccionados durante un proceso de extracción. Las actividades muestran cómo recorrer una cadena utilizando diferentes saltos para obtener secuencias específicas de caracteres.

# %%
# Toma cada segundo elemento. Los elementos con índice 1, 3, 5 ...
Name[::2]
# Out:
# 'McalJcsn'

# %%
# Toma cada segundo elemento desde el índice 0 al 4
Name[0:5:2]
# Out:
# 'Mca'

# %% [markdown]
# ## Concatenar Cadenas
# En esta sección, se realizan ejercicios relacionados con la unión de cadenas de texto. A través de diferentes ejemplos, se explora cómo combinar varias cadenas para construir nuevos mensajes y cómo utilizar el operador de concatenación para integrar diferentes elementos en una sola expresión.

# %%
# Concatenar dos cadenas
Statement = Name + " is the best"
Statement
# Out:
# 'Michael Jackson is the best'

# %%
# Imprime la cadena 3 veces
3 * "Michael Jackson "
# Out:
# 'Michael Jackson Michael Jackson Michael Jackson '

# %%
# Concatenar cadenas
Name = "Michael Jackson"
Name = Name + " is the best"
Name
# Out:
# 'Michael Jackson is the best'

# %% [markdown]
# ## Secuencias de Escape

# %%
# Secuencia de escape para un Salto de línea
print(" Michael Jackson \n is the best" )
# Out:
#  Michael Jackson
#  is the best

# %%
# Secuencia de escape para un espacio de tabulación
print(" Michael Jackson \t is the best" )
# Out:
#  Michael Jackson 	 is the best

# %%
# Incluir una barra invertida en una cadena
print(" Michael Jackson \\ is the best" )
# Out:
#  Michael Jackson \ is the best

# %%
# La letra r le dirá a python que muestre la cadena tal cual e ignore lo que haya despues de la barra invertida
print(r" Michael Jackson \ is the best")
# Out:
#  Michael Jackson \ is the best

# %% [markdown]
# ## Operaciones con Cadenas
# En esta sección, se desarrollan actividades orientadas a la modificación y el procesamiento de cadenas de texto. Los ejercicios permiten aplicar diferentes operaciones para transformar, organizar y visualizar la información almacenada, fortaleciendo el manejo de datos textuales dentro del lenguaje Python.

# %%
# Convertir todos los caracteres de la cadena en mayúsculas
A = "Thriller is the sixth studio album"
print("before upper:", A)
B = A.upper()
print("After upper:", B)
# Out:
# before upper: Thriller is the sixth studio album
# After upper: THRILLER IS THE SIXTH STUDIO ALBUM

# %%
# Reemplazar la vieja sub-cadena por una nueva
A = "Michael Jackson is the best"
B = A.replace('Michael', 'Janet')
B
# Out:
# 'Janet Jackson is the best'

# %%
# Encontrar la sub-cadena. El resultado será unicamente el índice del primer elemente de la sub-cadena dentro de la cadena principal.
Name = "Michael Jackson"
Name.find('el')
# Out:
# 5

# %%
# Encotrar la sub-cadena dentro de la cadena.
Name.find('Jack')
# Out:
# 8

# %%
# Si no se encuentra la sub-cadena en la cadena principal
Name.find('Jasdfasdasdf')
# Out:
# -1

# %% [markdown]
# ### **EXAMEN**

# %%
# ¿Cual es el valor de la variable A después de ejecutar el siguiente código?
A = "1"
A
# Out:
# '1'

# %%
# ¿Cual es el valor de la variable B después de ejecutar el siguiente código?
B = "2"
B
# Out:
# '2'

# %%
#¿Cual es el valor de la variable C después de ejecutar el siguiente código?
C = A + B
C
# Out:
# '12'

# %%
#En la variable D haz uso del slicing para imprimir solo los primeros tres elementos:
D = "ABCDEFG"
D[0:3]
# Out:
# 'ABC'

# %%
#Usa un valor de stride de 2 para imprimir cada segundo elemento de la cadena E:
E = 'clocrkr1e1c1t'
E[::2]
# Out:
# 'correct'

# %%
#Imprime una barra invertida:
print ("\\")
# Out:
# \

# %%
#Convierte el mayúsculas el contenido de la variable F:
F = "You are wrong"
F = F.upper()
F
# Out:
# 'YOU ARE WRONG'

# %%
#En la variable G, encuentra el primer índice de la sub-cadena snow:
G = "Mary had a little lamb Little lamb, little lamb Mary had a little lamb \
Its fleece was white as snow And everywhere that Mary went Mary went, Mary went \
Everywhere that Mary went The lamb was sure to go"

G.find('snow')
# Out:
# 95

# %%
#En la variable G, reemplaza la sub-cadena Mary con Bob:
G = G.replace('Mary', 'Bob')
G
# Out:
# 'Bob had a little lamb Little lamb, little lamb Bob had a little lamb Its fleece was white as snow And everywhere that Bob went Bob went, Bob went Everywhere that Bob went The lamb was sure to go'

# %% [markdown]
# ### **CONCLUSIÓN CUADERNO**
# En el primer cuaderno se desarrolló ejercicios relacionados con el manejo de cadenas de texto en Python. A través de diferentes actividades, se logró explorar conceptos como la creación de cadenas, el acceso a los caracteres mediante índices positivos y negativos, la extracción de fragmentos de texto utilizando slicing, el uso de intervalos para recorrer una cadena y la concatenación de cadenas. Estas actividades permititieron comprender cómo almacenar, acceder y manipular información textual dentro de un programa.

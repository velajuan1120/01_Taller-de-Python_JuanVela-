# %%
#MENOR DE DOS PARES: Escriba una función que devuelva el menor de dos números dados si ambos números son pares, pero devuelva el mayor si uno o ambos números son impares
#lesser_of_two_evens(2,4) --> 2
#lesser_of_two_evens(2,5) --> 5

def lesser_of_two_evens(a,b):
  if a % 2== 0 and b % 2 == 0:
    return min(a,b)
  else:
    return max(a,b)

print(lesser_of_two_evens(2,4))
print(lesser_of_two_evens(2,5))
# Out:
# 2
# 5

# %%
#GALLETAS DE ANIMALES: Escribir una función que toma una cadena de dos palabras y devuelve True si ambas palabras comienzan con la misma letra
#animal_crackers('Ciudad Calor') --> True
#animal_crackers('Lugar Frio') --> False

def animal_crackers(texto):

    palabras = texto.split()
    primera = palabras[0]
    segunda = palabras[1]

    if primera[0] == segunda[0]:
        return True
    else:
        return False
print(animal_crackers("Ciudad Calor"))

print(animal_crackers("Lugar Frio"))
# Out:
# True
# False

# %%
#HACE VEINTE: dados dos enteros, devuelve True si la suma de los enteros es 20 o si uno de los enteros es 20. De lo contrario, devuelve False
#makes_twenty(20,10) --> True
#makes_twenty(12,8) --> True
#makes_twenty(2,3) --> False

def makes_twenty(a, b):
    if a == 20 or b == 20:
        return True
    elif a + b == 20:
        return True
    else:
        return False
print(makes_twenty(20, 10))
print(makes_twenty(12, 8))
print(makes_twenty(2, 3))
# Out:
# True
# True
# False

# %%
#Nivel 1
#MAYÚSCULAS: Escribir una función que haga mayúscula la primera y cuarta letra de una cadena de texto
def old_macdonald(nombre):

    primera_parte = nombre[:3].capitalize()
    segunda_parte = nombre[3:].capitalize()
    return primera_parte + segunda_parte

print(old_macdonald("macdonald"))
# Out:
# MacDonald

# %%
#REVERSA: Dada una oración, retornar la misma oración pero en reversa
def master_yoda(frase):

    palabras = frase.split()
    palabras_invertidas = palabras[::-1]
    return " ".join(palabras_invertidas)

print(master_yoda("I am home"))
print(master_yoda("We are ready"))
# Out:
# home am I
# ready are We

# %%
#Nivel 2
#PROBLEMA 33:Dada una lista de enteros, retornar True si el arreglo tinene un 3 seguido por un 3 .

def has_33(lista):
    for i in range(len(lista) - 1):
        if lista[i] == 3 and lista[i + 1] == 3:
            return True
    return False

print(has_33([1, 3, 3]))
print(has_33([1, 3, 1, 3]))
print(has_33([3, 1, 3]))
# Out:
# True
# False
# False

# %%
#REPLICADOR: Dada una cadena, devuelve una cadena donde por cada carácter en el original hay tres caracteres REPETIDOS

def paper_doll(texto):
    resultado = ""
    for letra in texto:
        resultado = resultado + letra * 3
    return resultado

print(paper_doll("Hello"))
print(paper_doll("Mississippi"))
# Out:
# HHHeeellllllooo
# MMMiiissssssiiissssssiiippppppiii

# %%
#BLACKJACK: Dados tres enteros entre 1 y 11, si su suma es menor o igual a 21, devuelve su suma. Si su suma excede 21 y hay un once, reduce la suma total en 10. Finalmente, si la suma (incluso después del ajuste) excede 21, devuelve 'BUST'

def blackjack(a, b, c):
    suma = a + b + c
    if suma <= 21:
        return suma
    elif suma > 21 and (a == 11 or b == 11 or c == 11):
        suma = suma - 10
        if suma <= 21:
            return suma
        else:
            return "BUST"
    else:
        return "BUST"

print(blackjack(5, 6, 7))
print(blackjack(9, 9, 9))
print(blackjack(9, 9, 11))
# Out:
# 18
# BUST
# 19

# %% [markdown]
# ## CONCLUSIÓN
# El desarrollo de este taller permitió fortalecer los conocimientos fundamentales del lenguaje de programación Python mediante la realización de diferentes ejercicios prácticos relacionados con el manejo de cadenas, tuplas, listas, conjuntos, diccionarios, estructuras condicionales, ciclos, funciones y programación orientada a objetos. Cada actividad contribuyó al desarrollo de habilidades orientadas al almacenamiento, la manipulación y el procesamiento de la información mediante el uso de diferentes estructuras y herramientas del lenguaje.
#
# Además, la documentación de cada uno de los cuadernos permitió comprender la importancia de mantener un código organizado, legible y correctamente estructurado. Los conocimientos adquiridos durante el desarrollo del taller constituyen una base sólida para abordar problemas más complejos relacionados con el procesamiento de datos a gran escala y el desarrollo de aplicaciones utilizando Python.
